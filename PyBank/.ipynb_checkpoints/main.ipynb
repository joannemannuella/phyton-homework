# %%
"""Homework : Sales Analysis.

This script will use the Pathlib library to set the file path,
use the csv library to read in the file, and iterate over each
row of the file to calculate profit and loss.
"""



#  Import the pathlib and csv library
from pathlib import Path
import csv

csvpath = Path('budget_data.csv')

# Opening input path as file object
with open(csvpath, "r") as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")
    csv_header = next(csvreader)

# initialized variables
    months = 0
    months+=1
    net_profit_loss = 0
    net_change_list = []
    previous_revenue = 0
    list_profits = []
    date = []
    first_row = next(csvreader)
    net_profit_loses = int(first_row[1])
    previous_revenue = int(first_row[1])

    
    # Read each row data after the header
    for row in csvreader:
        # printing row
        date.append(row[0])
        profit_loss = int(row[1])
        print(row)
      
    # Total number of month included in the data set
        months+=1
        total_months = 0
        total_months+=months
    #Net total of Profit/losses entire period
        net_profit_loses+=profit_loss
    #Track change of revenue to determine average changes in Profit/Losses over the entire period
        change = profit_loss - previous_revenue
        
        previous_revenue = int(row[1])
        
        net_change_list.append(change)
        
        previous_revenue = profit_loss
      
        list_profits = list_profits + [change]
        
       
average_change = round(sum(net_change_list)/ len(net_change_list),2)
print(average)
print(months)
print(net_profit_loses)

#The greatest increase in profits (date and amount) over the entire period.


greatest_increase = max(list_profits)
greatest_increase_index = list_profits.index(greatest_increase)
greatest_inc_date = date[greatest_increase_index]
print(greatest_increase ,greatest_inc_date)

#The greatest decrease in profits (date and amount) over the entire period.

greatest_decrease = min(list_profits)
greatest_decrease_index = list_profits.index(greatest_decrease)
greatest_dec_date = date[greatest_decrease_index]
print(greatest_decrease ,greatest_dec_date)

#print analysis output

printoutput = (
    f"Financial Analysis\n"
    f"-------------------------------------\n"
    f"Total Months: {str(months)}\n"
    f"Total: ${str(net_profit_loses)}\n"
    f"Average Change: ${str(round(average_change,2))}\n"
    f"Greatest Increase in Profits: {greatest_inc_date} (${str(greatest_increase)})\n"
    f"Greatest Decrease in Profits: {greatest_dec_date} (${str(greatest_decrease)})\n")
print(printoutput)
#Exporting to text file


output = Path("financial_analysis.txt")

 
            
with open(output, 'w') as txt_file:
    txt_file.write(printoutput)
# Out:
# ['Feb-2010', '984655']
# ['Mar-2010', '322013']
# ['Apr-2010', '-69417']
# ['May-2010', '310503']
# ['Jun-2010', '522857']
# ['Jul-2010', '1033096']
# ['Aug-2010', '604885']
# ['Sep-2010', '-216386']
# ['Oct-2010', '477532']
# ['Nov-2010', '893810']
# ['Dec-2010', '-80353']
# ['Jan-2011', '779806']
# ['Feb-2011', '-335203']
# ['Mar-2011', '697845']
# ['Apr-2011', '793163']
# ['May-2011', '485070']
# ['Jun-2011', '584122']
# ['Jul-2011', '62729']
# ['Aug-2011', '668179']
# ['Sep-2011', '899906']
# ['Oct-2011', '834719']
# ['Nov-2011', '132003']
# ['Dec-2011', '309978']
# ['Jan-2012', '-755566']
# ['Feb-2012', '1170593']
# ['Mar-2012', '252788']
# ['Apr-2012', '1151518']
# ['May-2012', '817256']
# ['Jun-2012', '570757']
# ['Jul-2012', '506702']
# ['Aug-2012', '-1022534']
# ['Sep-2012', '475062']
# ['Oct-2012', '779976']
# ['Nov-2012', '144175']
# ['Dec-2012', '542494']
# ['Jan-2013', '359333']
# ['Feb-2013', '321469']
# ['Mar-2013', '67780']
# ['Apr-2013', '471435']
# ...
